# %% [markdown]
# <a href="https://colab.research.google.com/github/HAL23/hal23.github.io/blob/master/scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# coding: UTF-8
import pandas as pd
from bs4 import BeautifulSoup
import requests

# アクセスするURL = ニュートピ
url = "https://newstopics.jp/"

# htmlを取得、BeautifulSoupで扱う
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser') # BeautifulSoupの初期化

# aタグの中から、class=titleの含まれたものを取得
tags = soup.find_all("a", {"class": "title"})
# データフレームを作成。列名 name=記事名, url=url
columns = ["name", "url"]
df = pd.DataFrame(columns=columns) 

# 抽出したa要素を行列に入れ込む
for tag in tags:
    name = tag.string #　記事名の取得
    url = tag.get("href") #リンクの取得
    se = pd.Series([name, url], columns) # 行を追加
    print(se)
    df = df.append(se, columns)
# Out:
# name    Apple、クレジットカード｢Appleカード｣を2019年夏ローンチ | ギズモード・ジャパン
# url                                         /url/5839018
# dtype: object
# name    iPhoneで使える「Apple Card」登場、2％還元で年会費・手数料ナシ - Enga...
# url                                          /url/5839188
# dtype: object
# name    物理Apple Cardは驚きのチタン製。名前のみが記載される「最も安全なクレジットカード」...
# url                                          /url/5839384
# dtype: object
# name    【26日 午前2時】｢Appleスペシャルイベント｣リアルタイム更新やります。みんな、夜更か...
# url                                          /url/5830996
# dtype: object
# name    田中圭さん出演の「MOW（モウ）」新CM放映開始！『アイス屋MOW』篇　3月28日（木）より...
# url                                          /url/5838003
# dtype: object
# name    Appleのクレカ｢Apple Card｣について今わかっていることまとめ | ギズモード・...
# url                                          /url/5840242
# dtype: object
# name    速報：アップル、定額ゲームサービスApple Arcade発表。100本以上の新作・独占作を...
# url                                          /url/5839027
# dtype: object
# name    ASCII.jp：アップル、カード番号が書かれていない、まったく新しいクレカ「Apple C...
# url                                          /url/5839017
# dtype: object
# name    今日のAppleイベントで発表されたものまとめ！ サービス4つ、ハードも1つ!? | ギズモ...
# url                                          /url/5841972
# dtype: object
# name    任天堂、新型Switchは上位版・廉価版を夏にも発売。「形に驚く」？(WSJ) - Enga...
# url                                          /url/5835826
# dtype: object
# name    Appleカードの物理カード、ミニマルの極みって感じで超カッコいいんだけど！ | ギズモード...
# url                                          /url/5839019
# dtype: object
# name    AppleがiPhoneと連動させる独自クレジットカード「Apple Card」を発表 - ...
# url                                          /url/5839033
# dtype: object
# name    Apple、製品は発表なし。クレカ、サブスク参入。スペシャルイベントでリリースされた全貌を1分で
# url                                         /url/5841557
# dtype: object
# name    Apple、雑誌の定期購読サービス｢AppleNews+｣発表 | ギズモード・ジャパン
# url                                     /url/5838785
# dtype: object
# name    【.biz】Dynabook、法人向けのコンパクトデスクトップ「dynaDesk」  - P...
# url                                          /url/5833187
# dtype: object
# name    ゲームのサブスクリプション｢AppleArcade｣今秋スタート予定 | ギズモード・ジャパン
# url                                        /url/5839133
# dtype: object
# name    こうしてGoogleに入社した(kumagi編) - Software Transactio...
# url                                          /url/5842413
# dtype: object
# name    エンタメへ飛び込め。新サービス｢Apple tv channel｣が発表 | ギズモード・ジャパン
# url                                          /url/5839191
# dtype: object
# name    Appleが独自のサブスクリプション型ゲームサービス「Apple Arcade」を発表 - ...
# url                                          /url/5839371
# dtype: object
# name    新ゲームサービス｢Apple Arcade｣について知っておくべきことすべて | ギズモード...
# url                                          /url/5839758
# dtype: object
# name    サイゲームス「ウマ娘」が“事前登録1周年”を迎える　ファンからは「いつまでも待つ」の声 - ...
# url                                          /url/5834409
# dtype: object
# name    新ニュースサービス｢Apple News+｣について知っておくべきことすべて | ギズモード...
# url                                          /url/5839584
# dtype: object
# name    Apple TVの｢TV アプリ｣がAmazon Fire TVに対応！ Apple TVは...
# url                                          /url/5839222
# dtype: object
# name    高度10cmの空飛ぶバイク「Speeder」を製品化、5月より予約開始 - CNET Japan
# url                                         /url/5836093
# dtype: object
# name    オリジナルの動画配信サービス「Apple TV+」発表　2019年秋から提供 - ITmed...
# url                                          /url/5840076
# dtype: object
# name    入所者がおやつ詰まらせ死亡、介助の准看護師に有罪判決：朝日新聞デジタル
# url                            /url/5832155
# dtype: object
# name    相場の2倍で中古PCを"譲る"団体の言い分 | プレジデントオンライン
# url                            /url/5833260
# dtype: object
# name    「あなたブラクラ貼ったでしょ？」→39歳男性を書類送検　検挙男性が明かす「兵庫県警“決めつけ...
# url                                          /url/5764373
# dtype: object
# name    メテオフォール型開発 - 実践ゲーム製作メモ帳2
# url                 /url/2029940
# dtype: object
# name    女子小学生「袴」卒業式で見えた、思春期教育の後進国ニッポン - まぐまぐニュース！
# url                                  /url/5758173
# dtype: object
# name    「Googleマップが劣化した」不満の声が相次ぐ　ゼンリンとの契約解除で日本地図データを自社...
# url                                          /url/5787718
# dtype: object
# name    斜にかまえる、かまえないを1分ごとに切り替えるとどうなるか :: デイリーポータルZ
# url                                   /url/5781609
# dtype: object
# name    脊髄損傷の治療に光明　自分の細胞で神経再生、札幌医大の幹細胞治療 - Yahoo!ニュース
# url                                      /url/5731036
# dtype: object
# name    速報：Googleのゲームサービス『STADIA』発表。YouTubeのゲーム動画から即プレ...
# url                                          /url/5757036
# dtype: object
# name    【更新中】Googleの新ゲームサービス｢Stadia｣まとめ：これは歴史に残るぞ | ギズ...
# url                                          /url/5760065
# dtype: object
# name    iPhoneで使える「Apple Card」登場、2％還元で年会費・手数料ナシ - Enga...
# url                                          /url/5839188
# dtype: object
# name    物理Apple Cardは驚きのチタン製。名前のみが記載される「最も安全なクレジットカード」...
# url                                          /url/5839384
# dtype: object
# name    今日のAppleイベントで発表されたものまとめ！ サービス4つ、ハードも1つ!? | ギズモ...
# url                                          /url/5841972
# dtype: object
# name    Apple、クレジットカード｢Appleカード｣を2019年夏ローンチ | ギズモード・ジャパン
# url                                         /url/5839018
# dtype: object
# name    田中圭さん出演の「MOW（モウ）」新CM放映開始！『アイス屋MOW』篇　3月28日（木）より...
# url                                          /url/5838003
# dtype: object
